# %%
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import pdb
import torch
import numpy as np

# %%
#!pip install easydict bcolz-zipline mxnet

# %%
from config import get_config
import argparse
import matplotlib.pyplot as plt
from Learner import face_learner
from data.data_pipe import get_val_pair
from torchvision import transforms as trans

# %%
conf = get_config(training=False)

# %%
learner = face_learner(conf, inference=True)

# %%
learner.load_state(conf, 'ir_se50.pth', model_only=True, from_save_folder=True)

# %%
vgg2_fp, vgg2_fp_issame = get_val_pair(conf.emore_folder, 'vgg2_fp')
irse50_vgg2_tpr, irse50_vgg2_fpr, accuracy, best_threshold, roc_curve_tensor, val, far = learner.evaluate(conf, vgg2_fp, vgg2_fp_issame, nrof_folds=10, tta=True)
print('vgg2_fp - accuray:{}, threshold:{}, val:{}, far:{}'.format(accuracy, best_threshold, val, far))
#trans.ToPILImage()(roc_curve_tensor)

# %%
agedb_30, agedb_30_issame = get_val_pair(conf.emore_folder, 'agedb_30')
irse50_agedb30_tpr, irse50_agedb30_fpr, accuracy, best_threshold, roc_curve_tensor, val, far = learner.evaluate(conf, agedb_30, agedb_30_issame, nrof_folds=10, tta=True)
print('agedb_30 - accuray:{}, threshold:{}, val:{}, far:{}'.format(accuracy, best_threshold, val, far))
#trans.ToPILImage()(roc_curve_tensor)

# %%
calfw, calfw_issame = get_val_pair(conf.emore_folder, 'calfw')
irse50_calfw_tpr, irse50_calfw_fpr, accuracy, best_threshold, roc_curve_tensor, val, far = learner.evaluate(conf, calfw, calfw_issame, nrof_folds=10, tta=True)
print('calfw - accuray:{}, threshold:{}, val:{}, far:{}'.format(accuracy, best_threshold, val, far))
#trans.ToPILImage()(roc_curve_tensor)

# %%
cfp_ff, cfp_ff_issame = get_val_pair(conf.emore_folder, 'cfp_ff')
irse50_cfpff_tpr, irse50_cfpff_fpr, accuracy, best_threshold, roc_curve_tensor, val, far = learner.evaluate(conf, cfp_ff, cfp_ff_issame, nrof_folds=10, tta=True)
print('cfp_ff - accuray:{}, threshold:{}, val:{}, far:{}'.format(accuracy, best_threshold, val, far))
#trans.ToPILImage()(roc_curve_tensor)

# %%
cfp_fp, cfp_fp_issame = get_val_pair(conf.emore_folder, 'cfp_fp')
irse50_cfpfp_tpr, irse50_cfpfp_fpr, accuracy, best_threshold, roc_curve_tensor, val, far = learner.evaluate(conf, cfp_fp, cfp_fp_issame, nrof_folds=10, tta=True)
print('cfp_fp - accuray:{}, threshold:{}, val:{}, far:{}'.format(accuracy, best_threshold, val, far))
#trans.ToPILImage()(roc_curve_tensor)

# %%
cplfw, cplfw_issame = get_val_pair(conf.emore_folder, 'cplfw')
irse50_cplfw_tpr, irse50_cplfw_fpr, accuracy, best_threshold, roc_curve_tensor, val, far = learner.evaluate(conf, cplfw, cplfw_issame, nrof_folds=10, tta=True)
print('cplfw - accuray:{}, threshold:{}, val:{}, far:{}'.format(accuracy, best_threshold, val, far))
#trans.ToPILImage()(roc_curve_tensor)

# %%
lfw, lfw_issame = get_val_pair(conf.emore_folder, 'lfw')
irse50_lfw_tpr, irse50_lfw_fpr, accuracy, best_threshold, roc_curve_tensor, val, far = learner.evaluate(conf, lfw, lfw_issame, nrof_folds=10, tta=True)
print('lfw - accuray:{}, threshold:{}, val:{}, far:{}'.format(accuracy, best_threshold, val, far))
#trans.ToPILImage()(roc_curve_tensor)

# %%
conf = get_config(training=False)
conf.use_mobilfacenet = True

# %%
learner = face_learner(conf, inference=True)

# %%
learner.load_state(conf, 'mobilefacenet.pth', True, True)

# %%
vgg2_fp, vgg2_fp_issame = get_val_pair(conf.emore_folder, 'vgg2_fp')
mbf_vgg2_tpr, mbf_vgg2_fpr, accuracy, best_threshold, roc_curve_tensor, val, far = learner.evaluate(conf, vgg2_fp, vgg2_fp_issame, nrof_folds=10, tta=True)
print('vgg2_fp - accuray:{}, threshold:{}, val:{}, far:{}'.format(accuracy, best_threshold, val, far))
#trans.ToPILImage()(roc_curve_tensor)

# %%
agedb_30, agedb_30_issame = get_val_pair(conf.emore_folder, 'agedb_30')
mbf_agedb30_tpr, mbf_agedb30_fpr, accuracy, best_threshold, roc_curve_tensor, val, far = learner.evaluate(conf, agedb_30, agedb_30_issame, nrof_folds=10, tta=True)
print('agedb_30 - accuray:{}, threshold:{}, val:{}, far:{}'.format(accuracy, best_threshold, val, far))
#trans.ToPILImage()(roc_curve_tensor)

# %%
calfw, calfw_issame = get_val_pair(conf.emore_folder, 'calfw')
mbf_calfw_tpr, mbf_calfw_fpr, accuracy, best_threshold, roc_curve_tensor, val, far = learner.evaluate(conf, calfw, calfw_issame, nrof_folds=10, tta=True)
print('calfw - accuray:{}, threshold:{}, val:{}, far:{}'.format(accuracy, best_threshold, val, far))
#trans.ToPILImage()(roc_curve_tensor)

# %%
cfp_ff, cfp_ff_issame = get_val_pair(conf.emore_folder, 'cfp_ff')
mbf_cfpff_tpr, mbf_cfpff_fpr, accuracy, best_threshold, roc_curve_tensor, val, far = learner.evaluate(conf, cfp_ff, cfp_ff_issame, nrof_folds=10, tta=True)
print('cfp_ff - accuray:{}, threshold:{}, val:{}, far:{}'.format(accuracy, best_threshold, val, far))
#trans.ToPILImage()(roc_curve_tensor)

# %%
cfp_fp, cfp_fp_issame = get_val_pair(conf.emore_folder, 'cfp_fp')
mbf_cfpfp_tpr, mbf_cfpfp_fpr, accuracy, best_threshold, roc_curve_tensor, val, far = learner.evaluate(conf, cfp_fp, cfp_fp_issame, nrof_folds=10, tta=True)
print('cfp_fp - accuray:{}, threshold:{}, val:{}, far:{}'.format(accuracy, best_threshold, val, far))
#trans.ToPILImage()(roc_curve_tensor)

# %%
cplfw, cplfw_issame = get_val_pair(conf.emore_folder, 'cplfw')
mbf_cplfw_tpr, mbf_cplfw_fpr, accuracy, best_threshold, roc_curve_tensor, val, far = learner.evaluate(conf, cplfw, cplfw_issame, nrof_folds=10, tta=True)
print('cplfw - accuray:{}, threshold:{}, val:{}, far:{}'.format(accuracy, best_threshold, val, far))
#trans.ToPILImage()(roc_curve_tensor)

# %%
lfw, lfw_issame = get_val_pair(conf.emore_folder, 'lfw')
mbf_lfw_tpr, mbf_lfw_fpr, accuracy, best_threshold, roc_curve_tensor, val, far = learner.evaluate(conf, lfw, lfw_issame, nrof_folds=10, tta=True)
print('lfw - accuray:{}, threshold:{}, val:{}, far:{}'.format(accuracy, best_threshold, val, far))
#trans.ToPILImage()(roc_curve_tensor)

# %%
conf = get_config(training=False)
conf.use_facenet = True

# %%
learner = face_learner(conf, inference=True)

# %%
learner.load_state(conf, 'facenet.pth', model_only=True, from_save_folder=True)

# %%
vgg2_fp, vgg2_fp_issame = get_val_pair(conf.emore_folder, 'vgg2_fp')
fn_vgg2_tpr, fn_vgg2_fpr, accuracy, best_threshold, roc_curve_tensor, val, far = learner.evaluate(conf, vgg2_fp, vgg2_fp_issame, nrof_folds=10, tta=True, facenet = True)
print('vgg2_fp - accuray:{}, threshold:{}, val:{}, far:{}'.format(accuracy, best_threshold, val, far))
#trans.ToPILImage()(roc_curve_tensor)

# %%
agedb_30, agedb_30_issame = get_val_pair(conf.emore_folder, 'agedb_30')
fn_agedb30_tpr, fn_agedb30_fpr, accuracy, best_threshold, roc_curve_tensor, val, far = learner.evaluate(conf, agedb_30, agedb_30_issame, nrof_folds=10, tta=True, facenet = True)
print('agedb_30 - accuray:{}, threshold:{}, val:{}, far:{}'.format(accuracy, best_threshold, val, far))
#trans.ToPILImage()(roc_curve_tensor)

# %%
calfw, calfw_issame = get_val_pair(conf.emore_folder, 'calfw')
fn_calfw_tpr, fn_calfw_fpr, accuracy, best_threshold, roc_curve_tensor, val, far = learner.evaluate(conf, calfw, calfw_issame, nrof_folds=10, tta=True, facenet = True)
print('calfw - accuray:{}, threshold:{}, val:{}, far:{}'.format(accuracy, best_threshold, val, far))
#trans.ToPILImage()(roc_curve_tensor)

# %%
cfp_ff, cfp_ff_issame = get_val_pair(conf.emore_folder, 'cfp_ff')
fn_cfpff_tpr, fn_cfpff_fpr, accuracy, best_threshold, roc_curve_tensor, val, far = learner.evaluate(conf, cfp_ff, cfp_ff_issame, nrof_folds=10, tta=True, facenet = True)
print('cfp_ff - accuray:{}, threshold:{}, val:{}, far:{}'.format(accuracy, best_threshold, val, far))
#trans.ToPILImage()(roc_curve_tensor)

# %%
cfp_fp, cfp_fp_issame = get_val_pair(conf.emore_folder, 'cfp_fp')
fn_cfpfp_tpr, fn_cfpfp_fpr, accuracy, best_threshold, roc_curve_tensor, val, far = learner.evaluate(conf, cfp_fp, cfp_fp_issame, nrof_folds=10, tta=True, facenet = True)
print('cfp_fp - accuray:{}, threshold:{}, val:{}, far:{}'.format(accuracy, best_threshold, val, far))
#trans.ToPILImage()(roc_curve_tensor)

# %%
cplfw, cplfw_issame = get_val_pair(conf.emore_folder, 'cplfw')
fn_cplfw_tpr, fn_cplfw_fpr, accuracy, best_threshold, roc_curve_tensor, val, far = learner.evaluate(conf, cplfw, cplfw_issame, nrof_folds=10, tta=True, facenet = True)
print('cplfw - accuray:{}, threshold:{}, val:{}, far:{}'.format(accuracy, best_threshold, val, far))
#trans.ToPILImage()(roc_curve_tensor)

# %%
lfw, lfw_issame = get_val_pair(conf.emore_folder, 'lfw')
fn_lfw_tpr, fn_lfw_fpr, accuracy, best_threshold, roc_curve_tensor, val, far = learner.evaluate(conf, lfw, lfw_issame, nrof_folds=10, tta=True, facenet = True)
print('lfw - accuray:{}, threshold:{}, val:{}, far:{}'.format(accuracy, best_threshold, val, far))
#trans.ToPILImage()(roc_curve_tensor)

# %%
conf = get_config(training=False)
conf.use_ir18 = True

# %%
learner = face_learner(conf, inference=True)

# %%
learner.load_state(conf, 'ir18.pth', True, True)

# %%
vgg2_fp, vgg2_fp_issame = get_val_pair(conf.emore_folder, 'vgg2_fp')
ir18_vgg2_tpr, ir18_vgg2_fpr, accuracy, best_threshold, roc_curve_tensor, val, far = learner.evaluate(conf, vgg2_fp, vgg2_fp_issame, nrof_folds=10, tta=True)
print('vgg2_fp - accuray:{}, threshold:{}, val:{}, far:{}'.format(accuracy, best_threshold, val, far))
#trans.ToPILImage()(roc_curve_tensor)

# %%
agedb_30, agedb_30_issame = get_val_pair(conf.emore_folder, 'agedb_30')
ir18_agedb30_tpr, ir18_agedb30_fpr, accuracy, best_threshold, roc_curve_tensor, val, far = learner.evaluate(conf, agedb_30, agedb_30_issame, nrof_folds=10, tta=True)
print('agedb_30 - accuray:{}, threshold:{}, val:{}, far:{}'.format(accuracy, best_threshold, val, far))
#trans.ToPILImage()(roc_curve_tensor)

# %%
calfw, calfw_issame = get_val_pair(conf.emore_folder, 'calfw')
ir18_calfw_tpr, ir18_calfw_fpr, accuracy, best_threshold, roc_curve_tensor, val, far = learner.evaluate(conf, calfw, calfw_issame, nrof_folds=10, tta=True)
print('calfw - accuray:{}, threshold:{}, val:{}, far:{}'.format(accuracy, best_threshold, val, far))
#trans.ToPILImage()(roc_curve_tensor)

# %%
cfp_ff, cfp_ff_issame = get_val_pair(conf.emore_folder, 'cfp_ff')
ir18_cfpff_tpr, ir18_cfpff_fpr, accuracy, best_threshold, roc_curve_tensor, val, far = learner.evaluate(conf, cfp_ff, cfp_ff_issame, nrof_folds=10, tta=True)
print('cfp_ff - accuray:{}, threshold:{}, val:{}, far:{}'.format(accuracy, best_threshold, val, far))
#trans.ToPILImage()(roc_curve_tensor)

# %%
cfp_fp, cfp_fp_issame = get_val_pair(conf.emore_folder, 'cfp_fp')
ir18_cfpfp_tpr, ir18_cfpfp_fpr, accuracy, best_threshold, roc_curve_tensor, val, far = learner.evaluate(conf, cfp_fp, cfp_fp_issame, nrof_folds=10, tta=True)
print('cfp_fp - accuray:{}, threshold:{}, val:{}, far:{}'.format(accuracy, best_threshold, val, far))
#trans.ToPILImage()(roc_curve_tensor)

# %%
cplfw, cplfw_issame = get_val_pair(conf.emore_folder, 'cplfw')
ir18_cplfw_tpr, ir18_cplfw_fpr, accuracy, best_threshold, roc_curve_tensor, val, far = learner.evaluate(conf, cplfw, cplfw_issame, nrof_folds=10, tta=True)
print('cplfw - accuray:{}, threshold:{}, val:{}, far:{}'.format(accuracy, best_threshold, val, far))
#trans.ToPILImage()(roc_curve_tensor)

# %%
lfw, lfw_issame = get_val_pair(conf.emore_folder, 'lfw')
ir18_lfw_tpr, ir18_lfw_fpr, accuracy, best_threshold, roc_curve_tensor, val, far = learner.evaluate(conf, lfw, lfw_issame, nrof_folds=10, tta=True)
print('lfw - accuray:{}, threshold:{}, val:{}, far:{}'.format(accuracy, best_threshold, val, far))
#trans.ToPILImage()(roc_curve_tensor)

# %%
conf = get_config(training=False)
conf.use_trust_id = True

# %%
learner = face_learner(conf, inference=True)

# %%
vgg2_fp, vgg2_fp_issame = get_val_pair(conf.emore_folder, 'vgg2_fp')
trustid_vgg2_tpr, trustid_vgg2_fpr, accuracy, best_threshold, roc_curve_tensor, val, far = learner.evaluate(conf, vgg2_fp, vgg2_fp_issame, nrof_folds=10, tta=False, trust_id = True)
print('vgg2_fp - accuray:{}, threshold:{}, val:{}, far:{}'.format(accuracy, best_threshold, val, far))
#trans.ToPILImage()(roc_curve_tensor)

# %%
agedb_30, agedb_30_issame = get_val_pair(conf.emore_folder, 'agedb_30')
trustid_agedb30_tpr, trustid_agedb30_fpr, accuracy, best_threshold, roc_curve_tensor, val, far = learner.evaluate(conf, agedb_30, agedb_30_issame, nrof_folds=10, tta=False, trust_id = True)
print('agedb_30 - accuray:{}, threshold:{}, val:{}, far:{}'.format(accuracy, best_threshold, val, far))
#trans.ToPILImage()(roc_curve_tensor)

# %%
calfw, calfw_issame = get_val_pair(conf.emore_folder, 'calfw')
trustid_calfw_tpr, trustid_calfw_fpr, accuracy, best_threshold, roc_curve_tensor, val, far = learner.evaluate(conf, calfw, calfw_issame, nrof_folds=10, tta=False, trust_id = True)
print('calfw - accuray:{}, threshold:{}, val:{}, far:{}'.format(accuracy, best_threshold, val, far))
#trans.ToPILImage()(roc_curve_tensor)

# %%
cfp_ff, cfp_ff_issame = get_val_pair(conf.emore_folder, 'cfp_ff')
trustid_cfpff_tpr, trustid_cfpff_fpr, accuracy, best_threshold, roc_curve_tensor, val, far = learner.evaluate(conf, cfp_ff, cfp_ff_issame, nrof_folds=10, tta=False, trust_id = True)
print('cfp_ff - accuray:{}, threshold:{}, val:{}, far:{}'.format(accuracy, best_threshold, val, far))
#trans.ToPILImage()(roc_curve_tensor)

# %%
cfp_fp, cfp_fp_issame = get_val_pair(conf.emore_folder, 'cfp_fp')
trustid_cfpfp_tpr, trustid_cfpfp_fpr, accuracy, best_threshold, roc_curve_tensor, val, far = learner.evaluate(conf, cfp_fp, cfp_fp_issame, nrof_folds=10, tta=False, trust_id = True)
print('cfp_fp - accuray:{}, threshold:{}, val:{}, far:{}'.format(accuracy, best_threshold, val, far))
#trans.ToPILImage()(roc_curve_tensor)

# %%
cplfw, cplfw_issame = get_val_pair(conf.emore_folder, 'cplfw')
trustid_cplfw_tpr, trustid_cplfw_fpr, accuracy, best_threshold, roc_curve_tensor, val, far = learner.evaluate(conf, cplfw, cplfw_issame, nrof_folds=10, tta=False, trust_id = True)
print('cplfw - accuray:{}, threshold:{}, val:{}, far:{}'.format(accuracy, best_threshold, val, far))
#trans.ToPILImage()(roc_curve_tensor)

# %%
lfw, lfw_issame = get_val_pair(conf.emore_folder, 'lfw')
trustid_lfw_tpr, trustid_lfw_fpr, accuracy, best_threshold, roc_curve_tensor, val, far = learner.evaluate(conf, lfw, lfw_issame, nrof_folds=10, tta=False, trust_id = True)
print('lfw - accuray:{}, threshold:{}, val:{}, far:{}'.format(accuracy, best_threshold, val, far))
#trans.ToPILImage()(roc_curve_tensor)

# %%
irse50_vgg2_frr = np.array([1-tpr for tpr in irse50_vgg2_tpr])
fn_vgg2_frr = np.array([1-tpr for tpr in fn_vgg2_tpr])
mbf_vgg2_frr = np.array([1-tpr for tpr in mbf_vgg2_tpr])
ir18_vgg2_frr = np.array([1-tpr for tpr in ir18_vgg2_tpr])
trustid_vgg2_frr = np.array([1-tpr for tpr in trustid_vgg2_tpr])

irse50_agedb30_frr = np.array([1-tpr for tpr in irse50_agedb30_tpr])
fn_agedb30_frr = np.array([1-tpr for tpr in fn_agedb30_tpr])
mbf_agedb30_frr = np.array([1-tpr for tpr in mbf_agedb30_tpr])
ir18_agedb30_frr = np.array([1-tpr for tpr in ir18_agedb30_tpr])
trustid_agedb30_frr = np.array([1-tpr for tpr in trustid_agedb30_tpr])

irse50_calfw_frr = np.array([1-tpr for tpr in irse50_calfw_tpr])
fn_calfw_frr = np.array([1-tpr for tpr in fn_calfw_tpr])
mbf_calfw_frr = np.array([1-tpr for tpr in mbf_calfw_tpr])
ir18_calfw_frr = np.array([1-tpr for tpr in ir18_calfw_tpr])
trustid_calfw_frr = np.array([1-tpr for tpr in trustid_calfw_tpr])

irse50_cfpff_frr = np.array([1-tpr for tpr in irse50_cfpff_tpr])
fn_cfpff_frr = np.array([1-tpr for tpr in fn_cfpff_tpr])
mbf_cfpff_frr = np.array([1-tpr for tpr in mbf_cfpff_tpr])
ir18_cfpff_frr = np.array([1-tpr for tpr in ir18_cfpff_tpr])
trustid_cfpff_frr = np.array([1-tpr for tpr in trustid_cfpff_tpr])

irse50_cfpfp_frr = np.array([1-tpr for tpr in irse50_cfpfp_tpr])
fn_cfpfp_frr = np.array([1-tpr for tpr in fn_cfpfp_tpr])
mbf_cfpfp_frr = np.array([1-tpr for tpr in mbf_cfpfp_tpr])
ir18_cfpfp_frr = np.array([1-tpr for tpr in ir18_cfpfp_tpr])
trustid_cfpfp_frr = np.array([1-tpr for tpr in trustid_cfpfp_tpr])

irse50_cplfw_frr = np.array([1-tpr for tpr in irse50_cplfw_tpr])
fn_cplfw_frr = np.array([1-tpr for tpr in fn_cplfw_tpr])
mbf_cplfw_frr = np.array([1-tpr for tpr in mbf_cplfw_tpr])
ir18_cplfw_frr = np.array([1-tpr for tpr in ir18_cplfw_tpr])
trustid_cplfw_frr = np.array([1-tpr for tpr in trustid_cplfw_tpr])

irse50_lfw_frr = np.array([1-tpr for tpr in irse50_lfw_tpr])
fn_lfw_frr = np.array([1-tpr for tpr in fn_lfw_tpr])
mbf_lfw_frr = np.array([1-tpr for tpr in mbf_lfw_tpr])
ir18_lfw_frr = np.array([1-tpr for tpr in ir18_lfw_tpr])
trustid_lfw_frr = np.array([1-tpr for tpr in trustid_lfw_tpr])

# %%
plt.figure(figsize=(20, 8))
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title('ROC Curves for the VGG2 dataset')

plt.plot(irse50_vgg2_fpr, irse50_vgg2_tpr, label='ir-se50')
plt.plot(fn_vgg2_fpr, fn_vgg2_tpr, label='facenet')
plt.plot(mbf_vgg2_fpr, mbf_vgg2_tpr, label='mobilefacenet')
plt.plot(ir18_vgg2_fpr, ir18_vgg2_tpr, label='ir18')
plt.plot(trustid_vgg2_fpr, trustid_vgg2_tpr, label='trustid')

plt.legend()
plt.grid(True)
plt.show()
plt.savefig('pre_vgg2.png')

# %%
plt.figure(figsize=(20, 8))
plt.xlabel('FAR')
plt.ylabel('TAR')
plt.title('ROC Curves for the AGEDB30 dataset')

plt.plot(irse50_agedb30_fpr, irse50_agedb30_tpr, label='ir-se50')
plt.plot(fn_agedb30_fpr, fn_agedb30_tpr, label='facenet')
plt.plot(mbf_agedb30_fpr, mbf_agedb30_tpr, label='mobilefacenet')
plt.plot(ir18_agedb30_fpr, ir18_agedb30_tpr, label='ir18')
plt.plot(trustid_agedb30_fpr, trustid_agedb30_tpr, label='trustid')

plt.legend()
plt.grid(True)
plt.show()
plt.savefig('pre_agedb30.png')

# %%
plt.figure(figsize=(20, 8))
plt.xlabel('FAR')
plt.ylabel('TAR')
plt.title('ROC Curves for the CALFW dataset')

plt.plot(irse50_calfw_fpr, irse50_calfw_tpr, label='ir-se50')
plt.plot(fn_calfw_fpr, fn_calfw_tpr, label='facenet')
plt.plot(mbf_calfw_fpr, mbf_calfw_tpr, label='mobilefacenet')
plt.plot(ir18_calfw_fpr, ir18_calfw_tpr, label='ir18')
plt.plot(trustid_calfw_fpr, trustid_calfw_tpr, label='trustid')

plt.legend()
plt.grid(True)
plt.show()
plt.savefig('pre_calfw.png')

# %%
plt.figure(figsize=(20, 8))
plt.xlabel('FAR')
plt.ylabel('TAR')
plt.title('ROC Curves for the CFP-FF dataset')

plt.plot(irse50_cfpff_fpr, irse50_cfpff_tpr, label='ir-se50')
plt.plot(fn_cfpff_fpr, fn_cfpff_tpr, label='facenet')
plt.plot(mbf_cfpff_fpr, mbf_cfpff_tpr, label='mobilefacenet')
plt.plot(ir18_cfpff_fpr, ir18_cfpff_tpr, label='ir18')
plt.plot(trustid_cfpff_fpr, trustid_cfpff_tpr, label='trustid')

plt.legend()
plt.grid(True)
plt.show()
plt.savefig('pre_cfpff.png')

# %%
plt.figure(figsize=(20, 8))
plt.xlabel('FAR')
plt.ylabel('TAR')
plt.title('ROC Curves for the CFP-FP dataset')

plt.plot(irse50_cfpfp_fpr, irse50_cfpfp_tpr, label='ir-se50')
plt.plot(fn_cfpfp_fpr, fn_cfpfp_tpr, label='facenet')
plt.plot(mbf_cfpfp_fpr, mbf_cfpfp_tpr, label='mobilefacenet')
plt.plot(ir18_cfpfp_fpr, ir18_cfpfp_tpr, label='ir18')
plt.plot(trustid_cfpfp_fpr, trustid_cfpfp_tpr, label='trustid')

plt.legend()
plt.grid(True)
plt.show()
plt.savefig('pre_cfpfp.png')

# %%
plt.figure(figsize=(20, 8))
plt.xlabel('FAR')
plt.ylabel('TAR')
plt.title('ROC Curves for the CPLFW dataset')

plt.plot(irse50_cplfw_fpr, irse50_cplfw_tpr, label='ir-se50')
plt.plot(fn_cplfw_fpr, fn_cplfw_tpr, label='facenet')
plt.plot(mbf_cplfw_fpr, mbf_cplfw_tpr, label='mobilefacenet')
plt.plot(ir18_cplfw_fpr, ir18_cplfw_tpr, label='ir18')
plt.plot(trustid_cplfw_fpr, trustid_cplfw_tpr, label='trustid')

plt.legend()
plt.grid(True)
plt.show()
plt.savefig('pre_cplfw.png')

# %%
plt.figure(figsize=(20, 8))
plt.xlabel('FAR')
plt.ylabel('TAR')
plt.title('ROC Curves for the LFW dataset')

plt.plot(irse50_lfw_fpr, irse50_lfw_tpr, label='ir-se50')
plt.plot(fn_lfw_fpr, fn_lfw_tpr, label='facenet')
plt.plot(mbf_lfw_fpr, mbf_lfw_tpr, label='mobilefacenet')
plt.plot(ir18_lfw_fpr, ir18_lfw_tpr, label='ir18')
plt.plot(trustid_fw_fpr, trustid_lfw_tpr, label='trustid')

plt.legend()
plt.grid(True)
plt.show()
plt.savefig('pre_lfw.png')

# %%
plt.close()

# %%
#-----------------------------------------------------------------------------|------------|-----------------------------------------------------------------------------|
#-----------------------------------------------------------------------------| DTE curves |-----------------------------------------------------------------------------|
#-----------------------------------------------------------------------------|------------|-----------------------------------------------------------------------------|

# %%
def eer(far, frr, tolerance=1e-1):
    for frr_value, far_value in zip(frr, far):
        if np.isclose(frr_value, far_value, rtol=tolerance):
            return [far_value, frr_value]
    return None

# %%
plt.figure(figsize=(20, 8))
plt.xlabel('FAR')
plt.ylabel('FRR')
plt.title('DTE Curves for the VGG2 dataset')

#plt.xscale('log')
#plt.yscale('log')

plt.plot(irse50_vgg2_fpr, irse50_vgg2_frr, label='ir-se50')
eer_point = eer(irse50_vgg2_fpr, irse50_vgg2_frr)
print(eer_point)
plt.scatter(eer_point[0], eer_point[1])

plt.plot(fn_vgg2_fpr, fn_vgg2_frr, label='facenet')
eer_point = eer(fn_vgg2_fpr, fn_vgg2_frr)
plt.scatter(eer_point[0], eer_point[1])

plt.plot(mbf_vgg2_fpr, mbf_vgg2_frr, label='mobilefacenet')
eer_point = eer(mbf_vgg2_fpr, mbf_vgg2_frr)
plt.scatter(eer_point[0], eer_point[1])

plt.plot(ir18_vgg2_fpr, ir18_vgg2_frr, label='ir18')
eer_point = eer(ir18_vgg2_fpr, ir18_vgg2_frr)
plt.scatter(eer_point[0], eer_point[1])

plt.plot(trustid_vgg2_fpr, trustid_vgg2_frr, label='trustid')
eer_point = eer(trustid_vgg2_fpr, trustid_vgg2_frr)
plt.scatter(eer_point[0], eer_point[1], label = eer_point)

plt.plot([0, 1], [0, 1], linestyle='-', color='gray', label='Equality Line')

plt.legend()
plt.grid(True)
#plt.show()
plt.savefig('pre_vgg2_dte.png')
# Out:
# [0.060799999999999986, 0.06640000000000001]

# %%
plt.figure(figsize=(20, 8))
plt.xlabel('FRR')
plt.ylabel('TAR')
plt.title('DTE Curves for the AGEDB30 dataset')

plt.plot(irse50_agedb30_fpr, irse50_agedb30_frr, label='ir-se50')
eer_point = eer(irse50_agedb30_fpr, irse50_agedb30_frr)
plt.scatter(eer_point[0], eer_point[1])

plt.plot(fn_agedb30_fpr, fn_agedb30_frr, label='facenet')
eer_point = eer(fn_agedb30_fpr, fn_agedb30_frr)
plt.scatter(eer_point[0], eer_point[1])

plt.plot(mbf_agedb30_fpr, mbf_agedb30_frr, label='mobilefacenet')
eer_point = eer(mbf_agedb30_fpr, mbf_agedb30_frr)
plt.scatter(eer_point[0], eer_point[1])

plt.plot(ir18_agedb30_fpr, ir18_agedb30_frr, label='ir18')
eer_point = eer(ir18_agedb30_fpr, ir18_agedb30_frr)
plt.scatter(eer_point[0], eer_point[1])

plt.plot(trustid_agedb30_fpr, trustid_agedb30_frr, label='trustid')
eer_point = eer(trustid_agedb30_fpr, trustid_agedb30_frr)
plt.scatter(eer_point[0], eer_point[1])

plt.legend()
plt.grid(True)
plt.show()
plt.savefig('pre_agedb30_dte.png')

# %%
plt.figure(figsize=(20, 8))
plt.xlabel('FRR')
plt.ylabel('TAR')
plt.title('DTE Curves for the CALFW dataset')

plt.plot(irse50_calfw_fpr, irse50_calfw_frr, label='ir-se50')
eer_point = eer(irse50_calfw_fpr, irse50_calfw_frr)
plt.scatter(eer_point[0], eer_point[1])

plt.plot(fn_calfw_fpr, fn_calfw_frr, label='facenet')
eer_point = eer(fn_calfw_fpr, fn_calfw_frr)
plt.scatter(eer_point[0], eer_point[1])

plt.plot(mbf_calfw_fpr, mbf_calfw_frr, label='mobilefacenet')
eer_point = eer(mbf_calfw_fpr, mbf_calfw_frr)
plt.scatter(eer_point[0], eer_point[1])

plt.plot(ir18_calfw_fpr, ir18_calfw_frr, label='ir18')
eer_point = eer(ir18_calfw_fpr, ir18_calfw_frr)
plt.scatter(eer_point[0], eer_point[1])

plt.plot(trustid_calfw_fpr, trustid_calfw_frr, label='trustid')
eer_point = eer(trustid_calfw_fpr, trustid_calfw_frr)
plt.scatter(eer_point[0], eer_point[1], tolerance = 0.04)

plt.legend()
plt.grid(True)
plt.show()
plt.savefig('pre_calfw_dte.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[214], line 24
#      22 plt.plot(trustid_calfw_fpr, trustid_calfw_frr, label='trustid')
#      23 eer_point = eer(trustid_calfw_fpr, trustid_calfw_frr)
# ---> 24 plt.scatter(eer_point[0], eer_point[1], tolerance = 0.04)
#      26 plt.legend()
#      27 plt.grid(True)
#
# File /usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py:2790, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2785 @_copy_docstring_and_deprecators(Axes.scatter)
#    2786 def scatter(
#    2787         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2788         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2789         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2790     __ret = gca().scatter(
# ...

# %%
plt.figure(figsize=(20, 8))
plt.xlabel('FRR')
plt.ylabel('TAR')
plt.title('DTE Curves for the CFP-FF dataset')

plt.plot(irse50_cfpff_fpr, irse50_cfpff_frr, label='ir-se50')
eer_point = eer(irse50_cfpff_fpr, irse50_cfpff_frr)
plt.scatter(eer_point[0], eer_point[1])

plt.plot(fn_cfpff_fpr, fn_cfpff_frr, label='facenet')
eer_point = eer(fn_cfpff_fpr, fn_cfpff_frr)
plt.scatter(eer_point[0], eer_point[1])

plt.plot(mbf_cfpff_fpr, mbf_cfpff_frr, label='mobilefacenet')
eer_point = eer(mbf_cfpff_fpr, mbf_cfpff_frr)
plt.scatter(eer_point[0], eer_point[1])

plt.plot(ir18_cfpff_fpr, ir18_cfpff_frr, label='ir18')
eer_point = eer(ir18_cfpff_fpr, ir18_cfpff_frr)
plt.scatter(eer_point[0], eer_point[1])

plt.plot(trustid_cfpff_fpr, trustid_cfpff_frr, label='trustid')
eer_point = eer(trustid_cfpff_fpr, trustid_cfpff_frr)
plt.scatter(eer_point[0], eer_point[1])


plt.legend()
plt.grid(True)
plt.show()
plt.savefig('pre_cfpff_dte.png')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[204], line 24
#      22 plt.plot(trustid_cfpff_fpr, trustid_cfpff_frr, label='trustid')
#      23 eer_point = eer(trustid_cfpff_fpr, trustid_cfpff_frr)
# ---> 24 plt.scatter(eer_point[0], eer_point[1])
#      27 plt.legend()
#      28 plt.grid(True)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
plt.figure(figsize=(20, 8))
plt.xlabel('FRR')
plt.ylabel('TAR')
plt.title('DTE Curves for the CFP-FP dataset')

plt.plot(irse50_cfpfp_fpr, irse50_cfpfp_frr, label='ir-se50')
eer_point = eer(irse50_cfpfp_fpr, irse50_cfpfp_frr)
plt.scatter(eer_point[0], eer_point[1])

plt.plot(fn_cfpfp_fpr, fn_cfpfp_frr, label='facenet')
eer_point = eer(fn_cfpfp_fpr, fn_cfpfp_frr)
plt.scatter(eer_point[0], eer_point[1])

plt.plot(mbf_cfpfp_fpr, mbf_cfpfp_frr, label='mobilefacenet')
eer_point = eer(mbf_cfpfp_fpr, mbf_cfpfp_frr)
plt.scatter(eer_point[0], eer_point[1])

plt.plot(ir18_cfpfp_fpr, ir18_cfpfp_fpr, label='ir18')
eer_point = eer(ir18_cfpfp_fpr, ir18_cfpfp_fpr)
plt.scatter(eer_point[0], eer_point[1])

plt.plot(trustid_cfpfp_fpr, trustid_cfpfp_frr, label='trustid')
eer_point = eer(trustid_cfpfp_fpr, trustid_cfpfp_frr)
plt.scatter(eer_point[0], eer_point[1])

plt.legend()
plt.grid(True)
plt.show()
plt.savefig('pre_cfpfp_dte.png')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[205], line 24
#      22 plt.plot(trustid_cfpfp_fpr, trustid_cfpfp_frr, label='trustid')
#      23 eer_point = eer(trustid_cfpfp_fpr, trustid_cfpfp_frr)
# ---> 24 plt.scatter(eer_point[0], eer_point[1])
#      26 plt.legend()
#      27 plt.grid(True)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
plt.figure(figsize=(20, 8))
plt.xlabel('FRR')
plt.ylabel('TAR')
plt.title('DTE Curves for the CPLFW dataset')

plt.plot(irse50_cplfw_fpr, irse50_cplfw_frr, label='ir-se50')
eer_point = eer(irse50_cplfw_fpr, irse50_cplfw_frr)
plt.scatter(eer_point[0], eer_point[1])
            
plt.plot(fn_cplfw_fpr, fn_cplfw_frr, label='facenet')
eer_point = eer(fn_cplfw_fpr, fn_cplfw_frr)
plt.scatter(eer_point[0], eer_point[1])
            
plt.plot(mbf_cplfw_fpr, mbf_cplfw_frr, label='mobilefacenet')
eer_point = eer(mbf_cplfw_fpr, mbf_cplfw_frr)
plt.scatter(eer_point[0], eer_point[1])
            
plt.plot(ir18_cplfw_fpr, ir18_cplfw_frr, label='ir18')
eer_point = eer(ir18_cplfw_fpr, ir18_cplfw_frr)
plt.scatter(eer_point[0], eer_point[1])
            
plt.plot(trustid_cplfw_fpr, trustid_cplfw_frr, label='trustid')
eer_point = eer(trustid_cplfw_fpr, trustid_cplfw_frr)
plt.scatter(eer_point[0], eer_point[1])
            
plt.legend()
plt.grid(True)
plt.show()
plt.savefig('pre_cplfw_dte.png')

# %%
plt.figure(figsize=(20, 8))
plt.xlabel('FRR')
plt.ylabel('TAR')
plt.title('DTE Curves for the LFW dataset')

plt.plot(irse50_lfw_fpr, irse50_lfw_frr, label='ir-se50')
eer_point = eer(irse50_lfw_fpr, irse50_lfw_frr)
plt.scatter(eer_point[0], eer_point[1])
            
plt.plot(fn_cplfw_fpr, fn_cplfw_frr, label='facenet')
eer_point = eer(fn_lfw_fpr, fn_lfw_frr)
plt.scatter(eer_point[0], eer_point[1])
            
plt.plot(mbf_cplfw_fpr, mbf_cplfw_frr, label='mobilefacenet')
eer_point = eer(mbf_lfw_fpr, mbf_lfw_frr)
plt.scatter(eer_point[0], eer_point[1])
            
plt.plot(ir18_cplfw_fpr, ir18_cplfw_frr, label='ir18')
eer_point = eer(ir18_lfw_fpr, ir18_lfw_frr)
plt.scatter(eer_point[0], eer_point[1])
            
plt.plot(trustid_cplfw_fpr, trustid_cplfw_frr, label='trustid')
eer_point = eer(trustid_fw_fpr, trustid_lfw_frr)
plt.scatter(eer_point[0], eer_point[1])

plt.legend()
plt.grid(True)
plt.show()
plt.savefig('pre_lfw_dte.png')
